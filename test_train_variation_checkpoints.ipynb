# %% [markdown]
# ## Training

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: accelerate==0.19.0 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (0.19.0)
# Requirement already satisfied: anyio==3.7.0 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (3.7.0)
# Requirement already satisfied: appnope==0.1.3 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (0.1.3)
# Requirement already satisfied: argon2-cffi==21.3.0 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (21.3.0)
# Requirement already satisfied: argon2-cffi-bindings==21.2.0 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 5)) (21.2.0)
# Requirement already satisfied: arrow==1.2.3 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (1.2.3)
# Requirement already satisfied: asttokens==2.2.1 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 7)) (2.2.1)
# Requirement already satisfied: attrs==23.1.0 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 8)) (23.1.0)
# Requirement already satisfied: backcall==0.2.0 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 9)) (0.2.0)
# Requirement already satisfied: beautifulsoup4==4.12.2 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 10)) (4.12.2)
# Requirement already satisfied: bleach==6.0.0 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 11)) (6.0.0)
# Requirement already satisfied: certifi==2023.5.7 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 12)) (2023.5.7)
# Requirement already satisfied: cffi==1.15.1 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 13)) (1.15.1)
# Requirement already satisfied: charset-normalizer==3.1.0 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 14)) (3.1.0)
# Requirement already satisfied: comm==0.1.3 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 15)) (0.1.3)
# Requirement already satisfied: contourpy==1.0.7 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 16)) (1.0.7)
# Requirement already satisfied: cycler==0.11.0 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 17)) (0.11.0)
# Requirement already satisfied: debugpy==1.6.7 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 18)) (1.6.7)
# Requirement already satisfied: decorator==5.1.1 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 19)) (5.1.1)
# Requirement already satisfied: defusedxml==0.7.1 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 20)) (0.7.1)
# Requirement already satisfied: diffusers==0.16.1 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 21)) (0.16.1)
# Requirement already satisfied: einops==0.6.1 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 22)) (0.6.1)
# Requirement already satisfied: executing==1.2.0 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 23)) (1.2.0)
# Requirement already satisfied: fastjsonschema==2.17.1 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 24)) (2.17.1)
# Requirement already satisfied: filelock==3.12.0 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 25)) (3.12.0)
# Requirement already satisfied: fonttools==4.39.4 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 26)) (4.39.4)
# Requirement already satisfied: fqdn==1.5.1 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 27)) (1.5.1)
# Requirement already satisfied: fsspec==2023.5.0 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 28)) (2023.5.0)
# Requirement already satisfied: huggingface-hub==0.14.1 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 29)) (0.14.1)
# Requirement already satisfied: idna==3.4 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 30)) (3.4)
# Requirement already satisfied: importlib-metadata==6.6.0 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 31)) (6.6.0)
# Requirement already satisfied: ipykernel==6.23.1 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 32)) (6.23.1)
# Requirement already satisfied: ipython==8.13.2 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 33)) (8.13.2)
# Requirement already satisfied: ipython-genutils==0.2.0 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 34)) (0.2.0)
# Requirement already satisfied: ipywidgets==8.0.6 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 35)) (8.0.6)
# Requirement already satisfied: isoduration==20.11.0 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 36)) (20.11.0)
# Requirement already satisfied: jedi==0.18.2 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 37)) (0.18.2)
# Requirement already satisfied: Jinja2==3.1.2 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 38)) (3.1.2)
# Requirement already satisfied: jsonpointer==2.3 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 39)) (2.3)
# Requirement already satisfied: jsonschema==4.17.3 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 40)) (4.17.3)
# Requirement already satisfied: jupyter==1.0.0 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 41)) (1.0.0)
# Requirement already satisfied: jupyter-console==6.6.3 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 42)) (6.6.3)
# Requirement already satisfied: jupyter-events==0.6.3 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 43)) (0.6.3)
# Requirement already satisfied: jupyter_client==8.2.0 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 44)) (8.2.0)
# Requirement already satisfied: jupyter_core==5.3.0 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 45)) (5.3.0)
# Requirement already satisfied: jupyter_server==2.6.0 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 46)) (2.6.0)
# Requirement already satisfied: jupyter_server_terminals==0.4.4 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 47)) (0.4.4)
# Requirement already satisfied: jupyterlab-pygments==0.2.2 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 48)) (0.2.2)
# Requirement already satisfied: jupyterlab-widgets==3.0.7 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 49)) (3.0.7)
# Requirement already satisfied: kiwisolver==1.4.4 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 50)) (1.4.4)
# Requirement already satisfied: lab==7.3 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 51)) (7.3)
# Requirement already satisfied: MarkupSafe==2.1.2 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 52)) (2.1.2)
# Requirement already satisfied: matplotlib==3.7.1 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 53)) (3.7.1)
# Requirement already satisfied: matplotlib-inline==0.1.6 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 54)) (0.1.6)
# Requirement already satisfied: mistune==2.0.5 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 55)) (2.0.5)
# Requirement already satisfied: mpmath==1.3.0 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 56)) (1.3.0)
# Requirement already satisfied: nbclassic==1.0.0 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 57)) (1.0.0)
# Requirement already satisfied: nbclient==0.8.0 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 58)) (0.8.0)
# Requirement already satisfied: nbconvert==7.4.0 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 59)) (7.4.0)
# Requirement already satisfied: nbformat==5.8.0 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 60)) (5.8.0)
# Requirement already satisfied: nest-asyncio==1.5.6 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 61)) (1.5.6)
# Requirement already satisfied: networkx==3.1 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 62)) (3.1)
# Requirement already satisfied: notebook==6.5.4 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 63)) (6.5.4)
# Requirement already satisfied: notebook_shim==0.2.3 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 64)) (0.2.3)
# Requirement already satisfied: numpy==1.24.3 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 65)) (1.24.3)
# Requirement already satisfied: overrides==7.3.1 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 66)) (7.3.1)
# Requirement already satisfied: packaging==23.1 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 67)) (23.1)
# Requirement already satisfied: pandas==2.0.2 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 68)) (2.0.2)
# Requirement already satisfied: pandocfilters==1.5.0 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 69)) (1.5.0)
# Requirement already satisfied: parso==0.8.3 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 70)) (0.8.3)
# Requirement already satisfied: pexpect==4.8.0 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 71)) (4.8.0)
# Requirement already satisfied: pickleshare==0.7.5 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 72)) (0.7.5)
# Requirement already satisfied: Pillow==9.5.0 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 73)) (9.5.0)
# Requirement already satisfied: platformdirs==3.5.1 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 74)) (3.5.1)
# Requirement already satisfied: prometheus-client==0.17.0 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 75)) (0.17.0)
# Requirement already satisfied: prompt-toolkit==3.0.38 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 76)) (3.0.38)
# Requirement already satisfied: psutil==5.9.5 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 77)) (5.9.5)
# Requirement already satisfied: ptyprocess==0.7.0 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 78)) (0.7.0)
# Requirement already satisfied: pure-eval==0.2.2 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 79)) (0.2.2)
# Requirement already satisfied: pycparser==2.21 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 80)) (2.21)
# Requirement already satisfied: Pygments==2.15.1 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 81)) (2.15.1)
# Requirement already satisfied: pyparsing==3.0.9 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 82)) (3.0.9)
# Requirement already satisfied: pyrsistent==0.19.3 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 83)) (0.19.3)
# Requirement already satisfied: python-dateutil==2.8.2 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 84)) (2.8.2)
# Requirement already satisfied: python-json-logger==2.0.7 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 85)) (2.0.7)
# Requirement already satisfied: pytz==2023.3 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 86)) (2023.3)
# Requirement already satisfied: PyYAML==6.0 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 87)) (6.0)
# Requirement already satisfied: pyzmq==25.1.0 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 88)) (25.1.0)
# Requirement already satisfied: qtconsole==5.4.3 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 89)) (5.4.3)
# Requirement already satisfied: QtPy==2.3.1 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 90)) (2.3.1)
# Requirement already satisfied: regex==2023.5.5 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 91)) (2023.5.5)
# Requirement already satisfied: requests==2.31.0 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 92)) (2.31.0)
# Requirement already satisfied: rfc3339-validator==0.1.4 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 93)) (0.1.4)
# Requirement already satisfied: rfc3986-validator==0.1.1 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 94)) (0.1.1)
# Requirement already satisfied: scipy==1.10.1 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 95)) (1.10.1)
# Requirement already satisfied: Send2Trash==1.8.2 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 96)) (1.8.2)
# Requirement already satisfied: simplejson==3.19.1 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 97)) (3.19.1)
# Requirement already satisfied: six==1.16.0 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 98)) (1.16.0)
# Requirement already satisfied: sniffio==1.3.0 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 99)) (1.3.0)
# Requirement already satisfied: soupsieve==2.4.1 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 100)) (2.4.1)
# Requirement already satisfied: stack-data==0.6.2 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 101)) (0.6.2)
# Requirement already satisfied: sympy==1.12 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 102)) (1.12)
# Requirement already satisfied: terminado==0.17.1 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 103)) (0.17.1)
# Requirement already satisfied: tinycss2==1.2.1 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 104)) (1.2.1)
# Requirement already satisfied: tokenizers==0.13.3 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 105)) (0.13.3)
# Requirement already satisfied: torch==2.0.1 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 106)) (2.0.1)
# Requirement already satisfied: torchvision==0.15.2 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 107)) (0.15.2)
# Requirement already satisfied: tornado==6.3.2 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 108)) (6.3.2)
# Requirement already satisfied: tqdm==4.65.0 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 109)) (4.65.0)
# Requirement already satisfied: traitlets==5.9.0 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 110)) (5.9.0)
# Requirement already satisfied: transformers==4.29.2 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 111)) (4.29.2)
# Requirement already satisfied: txt2tags==3.8 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 112)) (3.8)
# Requirement already satisfied: typing_extensions==4.6.2 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 113)) (4.6.2)
# Requirement already satisfied: tzdata==2023.3 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 114)) (2023.3)
# Requirement already satisfied: uri-template==1.2.0 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 115)) (1.2.0)
# Requirement already satisfied: urllib3==2.0.2 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 116)) (2.0.2)
# Requirement already satisfied: wcwidth==0.2.6 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 117)) (0.2.6)
# Requirement already satisfied: webcolors==1.13 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 118)) (1.13)
# Requirement already satisfied: webencodings==0.5.1 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 119)) (0.5.1)
# Requirement already satisfied: websocket-client==1.5.2 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 120)) (1.5.2)
# Requirement already satisfied: widgetsnbextension==4.0.7 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 121)) (4.0.7)
# Requirement already satisfied: zipp==3.15.0 in /Users/glebershov/Diploma/env/lib/python3.11/site-packages (from -r requirements.txt (line 122)) (3.15.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import PIL
import torch
import os
from torchvision import transforms
from diffusers import AutoencoderKL

from torch.utils.data import Dataset
from torchvision.transforms import functional
from PIL import Image
import pandas as pd
from tqdm import tqdm
import math
import glob

# %%
from src.model import UNet, CLIPVision
from src.pipeline import MyPipline
pretrained_name = 'lambdalabs/sd-image-variations-diffusers'

# %%
vae = AutoencoderKL.from_pretrained(pretrained_name, subfolder='vae', revision='v2.0')

# %%
unet2 = UNet(path=pretrained_name, subfolder='unet', revision='v2.0')

# %%
clip = CLIPVision.from_pretrained(pretrained_name, subfolder='image_encoder', revision="v2.0")

# %%
sd_pipe = MyPipline(unet2, clip)
# Out:
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.

# %%
from utils import prepare_inference_im
inp_images = prepare_inference_im('./test_im')
print(inp_images[0].shape)
# Out:
# torch.Size([1, 3, 224, 224])

# %%
param_need_grads = []
for name, param in unet2.named_parameters():
    if 'attentions' in name:
        param.requires_grad = True
        param_need_grads.append(name)
    else:
        param.requires_grad = False

print(len(param_need_grads) / 2)
# Out:
# 416.0

# %%
from src.cofig import TrainingConfig
config = TrainingConfig()

# %%
relevant_poses = pd.read_pickle('./relevant_poses.pkl')

# %%
from src.dataset import FFHQDataset
dataset_ffhq = FFHQDataset('/content/ffhq', relevant_poses, size=config.image_size)
train_dataloader_ffhq = torch.utils.data.DataLoader(dataset_ffhq, batch_size=config.train_batch_size, shuffle=True)

# %%
from diffusers import DDPMScheduler
import torch.nn.functional as F

noise_scheduler = DDPMScheduler(num_train_timesteps=1000)

# %%
optimizer = torch.optim.AdamW(unet2.parameters(), lr=config.learning_rate)

# %%
from diffusers.optimization import get_cosine_schedule_with_warmup

lr_scheduler = get_cosine_schedule_with_warmup(
    optimizer=optimizer,
    num_warmup_steps=config.lr_warmup_steps,
    num_training_steps=(len(train_dataloader_ffhq) * config.num_epochs),
)

# %%
def make_grid(images, rows, cols):
    w, h = images[0].size
    grid = Image.new('RGB', size=(cols*w, rows*h))
    for i, image in enumerate(images):
        grid.paste(image, box=(i%cols*w, i//cols*h))
    return grid

def evaluate(config, epoch, pipeline):

    images = pipeline(
        # batch_size = config.eval_batch_size, 
        generator=torch.manual_seed(config.seed),
    ) # return a tuple
    
    image_grid = make_grid(images, rows=config.train_batch_size // 2, cols=config.train_batch_size // 2)

    test_dir = os.path.join(config.output_dir, "samples")
    os.makedirs(test_dir, exist_ok=True)
    image_grid.save(f"{test_dir}/{epoch:04d}.png")

def save_images(im, epoch):
    test_dir = os.path.join(config.output_dir, "samples")
    os.makedirs(test_dir, exist_ok=True)
    im[0].save(f"{test_dir}/{epoch:04d}.png")

# %%
pipe = MyPipline(unet2, clip)
# Out:
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.

# %%
from accelerate import Accelerator

def train_loop(config, model, noise_scheduler, optimizer, train_dataloader, lr_scheduler, vae, vit, inp_images):

    # accelerator
    accelerator = Accelerator(
        mixed_precision=config.mixed_precision,
        gradient_accumulation_steps=config.gradient_accumulation_steps,
        log_with="tensorboard", # change to wandb
        logging_dir=os.path.join(config.output_dir, "logs")
    )
    if accelerator.is_main_process:
        accelerator.init_trackers("train_example")

    # Have to unpack the
    # objects in the same order you gave them to the prepare method!!!
    model, optimizer, train_dataloader, lr_scheduler, vae, vit = accelerator.prepare(
        model, optimizer, train_dataloader, lr_scheduler, vae, vit
    )

    global_step = 0

    vae.eval()
    vit.train()

    model.train()

    for epoch in range(config.num_epochs):
        progress_bar = tqdm(total=len(train_dataloader), disable=not accelerator.is_local_main_process)
        progress_bar.set_description(f"Epoch {epoch}")

        for step, batch in enumerate(train_dataloader):
            poses = batch['diff_pose']
            latents = vae.encode(batch["pixel_values"]).latent_dist.sample().detach()
            latents = latents * 0.18215 # Why we mult latens on this constant?

            img_emb = vit(batch['pix_for_vit']).image_embeds.reshape(batch['pix_for_vit'].shape[0], 1, 768)


            # Sample noise to add to the images
            noise = torch.randn(latents.shape).to(latents.device)
            bs = latents.shape[0]

            # Sample a random timestep for each image
            timesteps = torch.randint(0, noise_scheduler.num_train_timesteps, (bs,), device=latents.device).long()

            # The forward diffusion process
            noisy_latents = noise_scheduler.add_noise(latents, noise, timesteps)

            with accelerator.accumulate(model):

                # Predict the noise residual
                noise_pred = model(noisy_latents, timesteps, img_emb, poses)["sample"]
                loss = F.mse_loss(noise_pred, noise)
                accelerator.backward(loss)

                accelerator.clip_grad_norm_(model.parameters(), 1.0)
                optimizer.step()
                lr_scheduler.step()
                optimizer.zero_grad()

            progress_bar.update(1)
            logs = {"loss": loss.detach().item(), "lr": lr_scheduler.get_last_lr()[0], "step": global_step}
            progress_bar.set_postfix(**logs)
            accelerator.log(logs, step=global_step)
            metrics = {"train/train_loss": loss.detach().item(),
                       "lr": lr_scheduler.get_last_lr()[0],
                       "step": global_step}
            # wandb.log({**metrics})
            global_step += 1

        # Save sample some demo images with evaluate() and save the model
        if accelerator.is_main_process:
            pipeline = MyPipline(unet=accelerator.unwrap_model(model), image_encoder=clip)

            if (epoch + 1) % config.save_image_epochs == 0 or epoch == config.num_epochs - 1:
                try:
                    im = pipeline(inp_images[0], torch.Tensor([[0., -1.]]))
                    save_images(im, epoch)
                    torch.save(accelerator.unwrap_model(model).state_dict(), f'model_{epoch % 3}.pth')
                except KeyboardInterrupt:
                    assert KeyboardInterrupt
                except Exception as err:
                    print(err.args)

# %%
from accelerate import notebook_launcher
from train import train_loop

torch.cuda.empty_cache() # pain 

args = (config, unet2, noise_scheduler, optimizer, train_dataloader_ffhq, lr_scheduler, vae, clip, inp_images)

notebook_launcher(train_loop, args, num_processes=1)

# %% [markdown]
# ## Eval

# %%
unet2.load_state_dict(torch.load('./model_new0.pth'))
# Out:
# <All keys matched successfully>

# %%
clip.load_state_dict(torch.load('./vit_10.pth'))
# Out:
# <All keys matched successfully>

# %%
clip.to('cuda')
vae.to('cuda')
unet2.to('cuda')

# %%
pipeline = MyPipline(unet2, clip)

# %%
import numpy as np
images = []
for s in np.linspace(-0.7, 0.7, 16):
    im = pipeline(inp_images[0],
              torch.Tensor([[0., s]]), 
              generator=torch.manual_seed(10), #10
              guidance_scale = 13, 
              num_inference_steps=100
              )
    images.append(im[0])

image_grid = make_grid(images, rows=4, cols=4)

# Save the images
image_grid.save(f"./rotation_test_8.png")
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
